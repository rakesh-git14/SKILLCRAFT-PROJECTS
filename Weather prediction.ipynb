# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the weather dataset
df = pd.read_csv("Date,Temperature,Humidity,WindSpeed 2.csv")

# Display basic info
print("📊 Weather Dataset Summary:")
print(df.describe())
print("\n🌦 Weather Counts:")
print(df['Weather'].value_counts())

# Plot temperature over time
plt.figure(figsize=(10, 5))
plt.plot(df['Date'], df['Humidity'], marker='o', color='Purple')
plt.title("Daily Temperature")
plt.xlabel("Date")
plt.ylabel("Temperature (°C)")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# Bar chart of weather type counts
df['Weather'].value_counts().plot(kind='bar', color='skyblue')
plt.title("Weather Type Frequency")
plt.xlabel("Weather")
plt.ylabel("Count")
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# 📊 Weather Dataset Summary:
#        Temperature   Humidity  WindSpeed
# count    42.000000  42.000000  42.000000
# mean     30.642857  63.190476  10.761905
# std       2.069776   8.282329   2.293251
# min      27.000000  48.000000   7.000000
# 25%      29.000000  57.250000   9.000000
# 50%      30.500000  65.000000  10.500000
# 75%      32.000000  69.750000  12.750000
# max      34.000000  77.000000  15.000000
#
# 🌦 Weather Counts:
# Weather
# Sunny     18
# Cloudy    12
# Rainy     12
# Name: count, dtype: int64
